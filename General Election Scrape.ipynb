# %% [markdown]
# ## Table of Contents
#
# 1. Introduction
# 2. Install & Import Packages
# 3. Access HTML and Create Selector Object
# 4. Scrape Data and Create Dataframes for States, Polls Closing, and Races to Watch
# 5. Concatenate & Style

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# It's hard to believe that it's finally Election Day. To reduce anxiety while watching results, it would be great to have poll closing times and key races to watch by state all in one place. We've scraped information from FiveThirtyEight (https://projects.fivethirtyeight.com/election-results-timing/) using scrapy and css, converted the Selector lists to dataframes, cleaned where necessary, including using .string, .split, and .get functions for string columns, and created a concatenated dataframe. Hopefully, it will help me avoid stress-binging 8-packs of Ferrero Rocher.

# %% [markdown]
# ## 2. Install & Import Packages

# %%
import pandas as pd

# !pip install scrapy
import scrapy
from scrapy import Selector
import requests
# Out:
# Requirement already satisfied: scrapy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.4.0)
# Requirement already satisfied: zope.interface>=4.1.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (5.1.2)
# Requirement already satisfied: itemadapter>=0.1.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (0.1.1)
# Requirement already satisfied: cssselect>=0.9.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: queuelib>=1.4.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (1.5.0)
# Requirement already satisfied: lxml>=3.5.0; platform_python_implementation == "CPython" in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (4.5.1)
# Requirement already satisfied: itemloaders>=1.0.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (1.0.3)
# Requirement already satisfied: w3lib>=1.17.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (1.22.0)
# Requirement already satisfied: Twisted>=17.9.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (20.3.0)
# Requirement already satisfied: service-identity>=16.0.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (18.1.0)
# Requirement already satisfied: protego>=0.1.15 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (0.1.16)
# Requirement already satisfied: pyOpenSSL>=16.2.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (19.1.0)
# Requirement already satisfied: cryptography>=2.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scrapy) (2.9.2)
# Requirement already satisfied: setuptools in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from zope.interface>=4.1.3->scrapy) (47.3.1.post20200622)
# Requirement already satisfied: six>=1.6.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from parsel>=1.5.0->scrapy) (1.15.0)
# Requirement already satisfied: jmespath>=0.9.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from itemloaders>=1.0.1->scrapy) (0.10.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from Twisted>=17.9.0->scrapy) (20.0.1)
# Requirement already satisfied: incremental>=16.10.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from Twisted>=17.9.0->scrapy) (17.5.0)
# Requirement already satisfied: PyHamcrest!=1.10.0,>=1.9.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from Twisted>=17.9.0->scrapy) (2.0.2)
# Requirement already satisfied: Automat>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from Twisted>=17.9.0->scrapy) (20.2.0)
# Requirement already satisfied: constantly>=15.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from Twisted>=17.9.0->scrapy) (15.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from Twisted>=17.9.0->scrapy) (19.3.0)
# Requirement already satisfied: pyasn1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from service-identity>=16.0.0->scrapy) (0.4.8)
# Requirement already satisfied: pyasn1-modules in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from service-identity>=16.0.0->scrapy) (0.2.8)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from cryptography>=2.0->scrapy) (1.14.0)
# Requirement already satisfied: idna>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from hyperlink>=17.1.1->Twisted>=17.9.0->scrapy) (2.9)
# Requirement already satisfied: pycparser in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.0->scrapy) (2.20)

# %% [markdown]
# ## 3. Access HTML and Create Selector Object

# %%
# Url containing html
url = "https://projects.fivethirtyeight.com/election-results-timing/"

# Get html source code using requests.get and .content and store in string html
html = requests.get(url).content

# Create the Selector object sel from html. Remember Selector returns a list
sel = Selector(text = html)

# Check number of html elements. We use xpath here, a space means all generations and * is a wildcard for any child elements
print("Number of elements in html document: ", len(sel.css(' *')))
# Out:
# Number of elements in html document:  1775

# %% [markdown]
# ## 4. Scrape Data and Create Dataframes for States, Polls Closing, and Races to Watch

# %% [markdown]
# ### States

# %%
# Scrape text of state names (inspecting html - in class state-name), Selector returns list
states = sel.css('.state-name::text').extract()

# Convert to dataframe
states = pd.DataFrame(states, columns=['States'])

# %% [markdown]
# ### Poll Closing

# %%
# Scrape text of poll closing (inspecting html, in p element class info-text within info-box last_polls_close class, use . for space in class), Selector returns list
polls_close = sel.css('.info-box.last_polls_close > p.info-text::text').extract()

# Convert to dataframe
polls_close = pd.DataFrame(polls_close, columns=['Polls Close (EST)'])

# Let's check
polls_close.head()
# Out:
#    Polls Close (EST)
# 0     8 p.m. Eastern
# 1     1 a.m. Eastern
# 2     9 p.m. Eastern
# 3  8:30 p.m. Eastern
# 4    11 p.m. Eastern

# %%
# Remove redundant 'Eastern' by splitting original string on ' Eastern' and taking first string using str.get(0)
polls_close['Polls Close (EST)'] = polls_close['Polls Close (EST)'].str.split(' Eastern').str.get(0)
polls_close.head()
# Out:
#   Polls Close (EST)
# 0            8 p.m.
# 1            1 a.m.
# 2            9 p.m.
# 3         8:30 p.m.
# 4           11 p.m.

# %% [markdown]
# ### Races to Watch

# %%
# Scrape text of races to watch (inspecting html, in p element class info-text within info-box races_to_watch class, use . for space in class), Selector returns list
races_to_watch = sel.css('.info-box.races_to_watch > p.info-text::text').extract()

# Convert to dataframe
races_to_watch = pd.DataFrame(races_to_watch, columns=['Races to Watch'])

# %% [markdown]
# ## 5. Concatenate & Style

# %%
# Dataframe has alot of companies and text so let's set row and column display options 
pd.set_option('display.max_colwidth', None)

# Concatenate 3 dataframes to create full dataframe 
state_polls = pd.concat([states,polls_close,races_to_watch], axis=1)

# Left justify the text using .style.set_properties. Left justify the column name using set_table_styles([dict(selector='th', props=[('text-align', 'left')
state_polls.style.set_properties(**{'text-align': 'left'}).set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
# Out:
# <style  type="text/css" >
#     #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dc th {
#           text-align: left;
#     }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow0_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow0_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow0_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow1_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow1_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow1_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow2_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow2_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow2_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow3_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow3_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow3_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow4_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow4_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow4_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow5_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow5_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow5_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow6_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow6_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow6_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow7_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow7_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow7_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow8_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow8_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow8_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow9_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow9_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow9_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow10_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow10_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow10_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow11_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow11_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow11_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow12_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow12_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow12_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow13_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow13_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow13_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow14_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow14_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow14_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow15_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow15_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow15_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow16_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow16_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow16_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow17_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow17_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow17_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow18_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow18_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow18_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow19_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow19_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow19_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow20_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow20_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow20_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow21_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow21_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow21_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow22_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow22_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow22_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow23_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow23_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow23_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow24_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow24_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow24_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow25_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow25_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow25_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow26_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow26_col1 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow26_col2 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow27_col0 {
#             text-align:  left;
#         }    #T_b2eb6cbe_1dea_11eb_86b3_4bf31a4131dcrow27_c
